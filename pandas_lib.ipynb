# %%
import pandas as pd

# %%
data = pd.read_csv('addresses.csv')

# %%
data
# Out:
#     id  location_id                   address_1  address_2  \
# 0    1            1       2600 Middlefield Road        NaN
# 1    2            2            24 Second Avenue        NaN
# 2    3            3            24 Second Avenue        NaN
# 3    4            4            24 Second Avenue        NaN
# 4    5            5            24 Second Avenue        NaN
# 5    6            6           800 Middle Avenue        NaN
# 6    7            7              500 Arbor Road        NaN
# 7    8            8           800 Middle Avenue        NaN
# 8    9            9       2510 Middlefield Road        NaN
# 9   10           10       1044 Middlefield Road        NaN
# 10  11           11         2140 Euclid Avenue.        NaN
# 11  12           12       1044 Middlefield Road  2nd Floor
# 12  13           13         399 Marine Parkway.        NaN
# 13  14           14          660 Veterans Blvd.        NaN
# 14  15           15        1500 Valencia Street        NaN
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
data.head(6)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
# 5   6            6      800 Middle Avenue       NaN    Menlo Park
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US
# 5             CA  94025-9881      US

# %%
data.tail()
# Out:
#     id  location_id                   address_1  address_2  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.tail(3)
# Out:
#     id  location_id                   address_1  address_2           city  \
# 18  19           19         19 West 39th Avenue        NaN      San Mateo
# 19  20           21          123 El Camino Real        NaN        Belmont
# 20  21           22  2013 Avenue of the fellows  Suite 100  San Francisco
#
#    state_province postal_code country
# 18             CA       94403      US
# 19             CA       94002      US
# 20             CA       94103      US

# %%
data.columns
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
data.head(3)
# Out:
#    id  location_id              address_1 address_2          city  \
# 0   1            1  2600 Middlefield Road       NaN  Redwood City
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US

# %%
data[['city', 'location_id']]
# Out:
#                    city  location_id
# 0          Redwood City            1
# 1             San Mateo            2
# 2             San Mateo            3
# 3             San Mateo            4
# 4             San Mateo            5
# 5            Menlo Park            6
# 6            Menlo Park            7
# 7            Menlo Park            8
# 8          Redwood City            9
# 9          Redwood City           10
# 10         Redwood City           11
# 11         Redwood City           12
# 12         Redwood City           13
# 13         Redwood City           14
# 14        San Francisco           15
# 15            Sunnyvale           16
# 16  South San Francisco           17
# 17         Redwood City           18
# 18            San Mateo           19
# 19              Belmont           21
# 20        San Francisco           22

# %%
data[['id', 'city', 'address_1']]
# Out:
#     id                 city                   address_1
# 0    1         Redwood City       2600 Middlefield Road
# 1    2            San Mateo            24 Second Avenue
# 2    3            San Mateo            24 Second Avenue
# 3    4            San Mateo            24 Second Avenue
# 4    5            San Mateo            24 Second Avenue
# 5    6           Menlo Park           800 Middle Avenue
# 6    7           Menlo Park              500 Arbor Road
# 7    8           Menlo Park           800 Middle Avenue
# 8    9         Redwood City       2510 Middlefield Road
# 9   10         Redwood City       1044 Middlefield Road
# 10  11         Redwood City         2140 Euclid Avenue.
# 11  12         Redwood City       1044 Middlefield Road
# 12  13         Redwood City         399 Marine Parkway.
# 13  14         Redwood City          660 Veterans Blvd.
# 14  15        San Francisco        1500 Valencia Street
# 15  16            Sunnyvale         1161 South Bernardo
# ...

# %%
type(data[['state_province']])
# Out:
# pandas.core.frame.DataFrame

# %%
type(data['state_province'])
# Out:
# pandas.core.series.Series

# %%
pd.read_excel('airline.xls')
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
pd.read_excel("airline1.xls")
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
pd.read_excel("airline1.xls" , sheet_name = "Sheet2")
# Out:
#     YEAR      Y      W       R      L      K
# 0   1948  1.214  0.243  0.1454  1.415  0.612
# 1   1949  1.354  0.260  0.2181  1.384  0.559
# 2   1950  1.569  0.278  0.3157  1.388  0.573
# 3   1951  1.948  0.297  0.3940  1.550  0.564
# 4   1952  2.265  0.310  0.3559  1.802  0.574
# 5   1953  2.731  0.322  0.3593  1.926  0.711
# 6   1954  3.025  0.335  0.4025  1.964  0.776
# 7   1955  3.562  0.350  0.3961  2.116  0.827
# 8   1956  3.979  0.361  0.3822  2.435  0.800
# 9   1957  4.420  0.379  0.3045  2.707  0.921
# 10  1958  4.563  0.391  0.3284  2.706  1.067
# 11  1959  5.385  0.426  0.3856  2.846  1.083

# %%
pd.read_excel("airline1.xls" , sheet_name = "Sheet3")
# Out:
#     1965.0000  9.1200     0.5640     0.5879     3.6230     2.2570
# 0        1966     10.512      0.586     0.5369      4.074      2.742
# 1        1967     13.020      0.622     0.4443      4.710      3.564
# 2        1968     15.261      0.666     0.3052      5.217      4.767
# 3        1969     16.313      0.731     0.2332      5.569      6.511
# 4        1970     16.002      0.831     0.1883      5.495      7.627
# 5        1971     15.876      0.906     0.2023      5.334      8.673
# 6        1972     16.662      1.000     0.2506      5.345      8.331
# 7        1973     17.014      1.056     0.2668      5.662      8.557
# 8        1974     19.305      1.131     0.2664      5.729      9.508
# 9        1975     18.721      1.247     0.2301      5.722      9.062
# 10       1976     19.250      1.375     0.3452      5.762      8.262
# 11       1977     20.647      1.544     0.4508      5.877      7.474
# 12       1978     22.726      1.703     0.5877      6.108      7.104

# %%
pd.read_excel("airline1.xls" , sheet_name = "Sheet3", header = None)
# Out:
#        0       1      2       3      4      5
# 0   1965   9.120  0.564  0.5879  3.623  2.257
# 1   1966  10.512  0.586  0.5369  4.074  2.742
# 2   1967  13.020  0.622  0.4443  4.710  3.564
# 3   1968  15.261  0.666  0.3052  5.217  4.767
# 4   1969  16.313  0.731  0.2332  5.569  6.511
# 5   1970  16.002  0.831  0.1883  5.495  7.627
# 6   1971  15.876  0.906  0.2023  5.334  8.673
# 7   1972  16.662  1.000  0.2506  5.345  8.331
# 8   1973  17.014  1.056  0.2668  5.662  8.557
# 9   1974  19.305  1.131  0.2664  5.729  9.508
# 10  1975  18.721  1.247  0.2301  5.722  9.062
# 11  1976  19.250  1.375  0.3452  5.762  8.262
# 12  1977  20.647  1.544  0.4508  5.877  7.474
# 13  1978  22.726  1.703  0.5877  6.108  7.104

# %%
data1 = pd.read_excel("airline1.xls" , sheet_name = "Sheet3", header = None, names = ['a','b','c','d','e','f'])

# %%
# saving excel file with pandas

data1.to_csv('test1.csv', index = False)

# %%
data1.to_excel('test2.xlsx')

# %%
type(data1.tail())
# Out:
# pandas.core.frame.DataFrame

# %%
data1.columns
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f'], dtype='object')

# %%
list(data1.columns)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %%
data1[['b', 'c']]
# Out:
#          b      c
# 0    9.120  0.564
# 1   10.512  0.586
# 2   13.020  0.622
# 3   15.261  0.666
# 4   16.313  0.731
# 5   16.002  0.831
# 6   15.876  0.906
# 7   16.662  1.000
# 8   17.014  1.056
# 9   19.305  1.131
# 10  18.721  1.247
# 11  19.250  1.375
# 12  20.647  1.544
# 13  22.726  1.703

# %%
data2 = pd.read_html("https://www.basketball-reference.com/leagues/NBA_2015_totals.html")

# %%
type(data2)
# Out:
# list

# %%
len(data2)
# Out:
# 1

# %%
data2[0]
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0      1      Quincy Acy  PF  24  NYK  68  22  1287  152  331  ...  .784   79
# 1      2    Jordan Adams  SG  20  MEM  30   0   248   35   86  ...  .609    9
# 2      3    Steven Adams   C  21  OKC  70  67  1771  217  399  ...  .502  199
# 3      4     Jeff Adrien  PF  28  MIN  17   0   215   19   44  ...  .579   23
# 4      5   Arron Afflalo  SG  29  TOT  78  72  2502  375  884  ...  .843   27
# ..   ...             ...  ..  ..  ...  ..  ..   ...  ...  ...  ...   ...  ...
# 670  490  Thaddeus Young  PF  26  TOT  76  68  2434  451  968  ...  .655  127
# 671  490  Thaddeus Young  PF  26  MIN  48  48  1605  289  641  ...  .682   75
# 672  490  Thaddeus Young  PF  26  BRK  28  20   829  162  327  ...  .606   52
# 673  491     Cody Zeller   C  22  CHO  62  45  1487  172  373  ...  .774   97
# 674  492    Tyler Zeller   C  25  BOS  82  59  1731  340  619  ...  .823  146
#
# ...

# %%
data2[0].to_csv('players.csv')

# %%
pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...
